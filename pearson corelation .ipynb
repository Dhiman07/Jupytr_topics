# %%
#pearson corelation,paranetric method
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb
import scipy
from scipy.stats.stats import pearsonr
# %matplotlib inline
rcParams['figure.figsize']=[5,4]
sb.set_style('whitegrid')
adress='C:/Users/Dhiman/mtcars.csv'
cars=pd.read_csv(adress)
cars.columns=['car_names','mpg','cyl1','disp','hp','drat','wt','qsec','vs','am','gear','carb']
sb.pairplot(cars)

# %%
x=cars[['mpg','hp','qsec','wt']]
sb.pairplot(x)

# %%
mpg=cars['mpg']
hp=cars['hp']
qsec=cars['qsec']
wt=cars['wt']
pearsonr_coefficient,p_value=pearsonr(mpg,hp)
print 'pearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
# Out:
#   File "<ipython-input-1-6d1b6f224a52>", line 6
#     print 'pearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient)
#                                                  ^
# SyntaxError: invalid syntax

# %%
#to calculate pearson coeffecient
corr=x.corr()
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %%
sb.heatmap(corr, xticklabels=corr.columns.values,yticklabels=corr.columns.values)
